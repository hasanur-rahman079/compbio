# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in the mmgbsa data file as a pandas DataFrame
data1 = pd.read_csv('26305-mmgbsa.csv' )
data2 = pd.read_csv("66728267-mmgbsa.csv")
# data3 = pd.read_csv("5281426_L-Properties.dat", delim_whitespace=True)
data4 = pd.read_csv("3397-mmgbsa.csv")

# %%
print(data1.columns)
# Out:
# Index(['title', 'r_psp_MMGBSA_dG_Bind', 'r_psp_MMGBSA_dG_Bind_Coulomb',
#        'r_psp_MMGBSA_dG_Bind_Covalent', 'r_psp_MMGBSA_dG_Bind_Hbond',
#        'r_psp_MMGBSA_dG_Bind_Lipo', 'r_psp_MMGBSA_dG_Bind_Packing',
#        'r_psp_MMGBSA_dG_Bind_SelfCont', 'r_psp_MMGBSA_dG_Bind_Solv_GB',
#        'r_psp_MMGBSA_dG_Bind_Solv_SA', 'r_psp_MMGBSA_dG_Bind_vdW',
#        'r_psp_Lig_Strain_Energy', 'r_psp_Lig_Strain_Coulomb',
#        'r_psp_Lig_Strain_Covalent', 'r_psp_Lig_Strain_Hbond',
#        'r_psp_Lig_Strain_Lipo', 'r_psp_Lig_Strain_Packing',
#        'r_psp_Lig_Strain_SelfCont', 'r_psp_Lig_Strain_Solv_GB',
#        'r_psp_Lig_Strain_Solv_SA', 'r_psp_Lig_Strain_vdW',
#        'r_psp_Ligand_Energy', 'r_psp_Ligand_Coulomb', 'r_psp_Ligand_Covalent',
#        'r_psp_Ligand_Hbond', 'r_psp_Ligand_Lipo', 'r_psp_Ligand_Packing',
#        'r_psp_Ligand_SelfCont', 'r_psp_Ligand_Solv_GB', 'r_psp_Ligand_Solv_SA',
#        'r_psp_Ligand_vdW', 'r_psp_Complex_Energy', 'r_psp_Complex_Coulomb',
# ...

# %%
# Rename columns in data1
new_columns = {}
for column in data1.columns:
    new_columns[column] = column.replace("r_psp_", "")
data1 = data1.rename(columns=new_columns)

# Rename columns in data2
new_columns = {}
for column in data2.columns:
    new_columns[column] = column.replace("r_psp_", "")
data2 = data2.rename(columns=new_columns)

# Rename columns in data4
new_columns = {}
for column in data4.columns:
    new_columns[column] = column.replace("r_psp_", "")
data4 = data4.rename(columns=new_columns)

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Create a new dataframe with only the selected columns
data_to_plot = pd.concat([data1[columns_to_plot], data2[columns_to_plot], data4[columns_to_plot]])

# Plot a bar chart
ax = data_to_plot.mean().plot.bar(figsize=(10, 6))
ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
ax.set_title("Average MMGBSA Energy per Interaction Type")
plt.show()

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Plot a bar chart for each data file separately
for i, data in enumerate([data1, data2, data4]):
    # Create a new dataframe with only the selected columns
    data_to_plot = data[columns_to_plot]

    # Calculate the mean value of each column
    mean_values = data_to_plot.mean()

    # Plot a bar chart with different color for each data file
    ax = mean_values.plot.bar(figsize=(10, 6), color=['C{}'.format(i), 'C{}'.format(i+3), 'C{}'.format(i+1), 'C{}'.format(i+4), 'C{}'.format(i+2), 'C{}'.format(i+5), 'C{}'.format(i+6)])
    ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
    ax.set_title("Average MMGBSA Energy per Interaction Type (Data{})".format(i+1))
    plt.show()

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Create a new figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot a bar chart for each data file in a separate subplot
for i, data in enumerate([data1, data2, data4]):
    # Create a new dataframe with only the selected columns
    data_to_plot = data[columns_to_plot]

    # Calculate the mean value of each column
    mean_values = data_to_plot.mean()

    # Plot a bar chart with different color for each data file in a separate subplot
    ax = mean_values.plot.bar(ax=axs[i], color=['C{}'.format(i), 'C{}'.format(i+3), 'C{}'.format(i+1), 'C{}'.format(i+4), 'C{}'.format(i+2), 'C{}'.format(i+5), 'C{}'.format(i+6)])
    ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
    ax.set_title("Average MMGBSA Energy per Interaction Type (Data{})".format(i+1))

# Set the title of the figure
fig.suptitle("Comparison of Average MMGBSA Energy per Interaction Type for Three Data Files")

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Create a new figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Define the colors to use for the bars in each subplot
colors = ['r', 'b', 'g']

# Plot a bar chart for each data file in a separate subplot
for i, data in enumerate([data1, data2, data4]):
    # Create a new dataframe with only the selected columns
    data_to_plot = data[columns_to_plot]

    # Calculate the mean value of each column
    mean_values = data_to_plot.mean()

    # Plot a bar chart with a different color for each bar in the subplot
    ax = mean_values.plot.bar(ax=axs[i], color=colors)
    ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
    ax.set_title("Average MMGBSA Energy per Interaction Type (Data{})".format(i+1))

# Set the title of the figure
fig.suptitle("Comparison of Average MMGBSA Energy per Interaction Type for Three Data Files")

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()


# i think you are gessing wrong, i want the only green colors of 1st subplot bars, red colors for 2nd subplot bars and green color for 3rd subplot bars. not different colors for every bars in a subplot, one colors for one subplotbar so that it gets easier to distingush. also add one legend for all the subplots

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Create a new figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Define the colors to use for each subplot
colors = ['g', 'r', 'b']

# Plot a bar chart for each data file in a separate subplot
for i, data in enumerate([data1, data2, data4]):
    # Create a new dataframe with only the selected columns
    data_to_plot = data[columns_to_plot]

    # Calculate the mean value of each column
    mean_values = data_to_plot.mean()

    # Plot a bar chart with a different color for each subplot
    ax = mean_values.plot.bar(ax=axs[i], color=colors[i])
    ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
    ax.set_title("Average MMGBSA Energy per Interaction Type (Data{})".format(i+1))

# Add a legend for all subplots
fig.legend(labels=['Data1', 'Data2', 'Data4'], loc='upper center')

# Set the title of the figure
fig.suptitle("Comparison of Average MMGBSA Energy per Interaction Type for Three Data Files")

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %%
# Select the columns to plot
columns_to_plot = ['MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb', 'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond', 'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Solv_GB', 'MMGBSA_dG_Bind_vdW']

# Create a new figure
fig, ax = plt.subplots(figsize=(10, 6))

# Define the colors to use for each data file
colors = ['purple', 'green', 'r']

# Plot a bar chart for each data file
for i, data in enumerate([data1, data2, data4]):
    # Create a new dataframe with only the selected columns
    data_to_plot = data[columns_to_plot]

    # Calculate the mean value of each column
    mean_values = data_to_plot.mean()

    # Plot a bar chart with a different color for each data file
    mean_values.plot.bar(ax=ax, color=colors[i], position=i, width=0.25)

# Set the x-axis tick labels
ax.set_xticks([0, 1, 2, 3, 4, 5, 6])
ax.set_xticklabels(columns_to_plot)

# Set the y-axis label and title of the plot
ax.set_ylabel("Average MMGBSA Energy (kcal/mol)")
ax.set_title("Comparison of Average MMGBSA Energy per Interaction Type for Three Data Files")

# Add a legend for the data files
ax.legend(labels=['Nodakenatin (CID: 26305)', 'Isowigtheone (CID: 66728267)', 'Flutamide (CID: 3397)'], loc='upper left')

# Show top values

# Add grid lines to separate the columns
ax.grid(axis='y')
ax.grid(axis='x', linestyle='--', alpha=0.5)
ax.set_axisbelow(True)


# Display the figure
plt.show()

# %%
print(data1.columns)
# Out:
# Index(['title', 'MMGBSA_dG_Bind', 'MMGBSA_dG_Bind_Coulomb',
#        'MMGBSA_dG_Bind_Covalent', 'MMGBSA_dG_Bind_Hbond',
#        'MMGBSA_dG_Bind_Lipo', 'MMGBSA_dG_Bind_Packing',
#        'MMGBSA_dG_Bind_SelfCont', 'MMGBSA_dG_Bind_Solv_GB',
#        'MMGBSA_dG_Bind_Solv_SA', 'MMGBSA_dG_Bind_vdW', 'Lig_Strain_Energy',
#        'Lig_Strain_Coulomb', 'Lig_Strain_Covalent', 'Lig_Strain_Hbond',
#        'Lig_Strain_Lipo', 'Lig_Strain_Packing', 'Lig_Strain_SelfCont',
#        'Lig_Strain_Solv_GB', 'Lig_Strain_Solv_SA', 'Lig_Strain_vdW',
#        'Ligand_Energy', 'Ligand_Coulomb', 'Ligand_Covalent', 'Ligand_Hbond',
#        'Ligand_Lipo', 'Ligand_Packing', 'Ligand_SelfCont', 'Ligand_Solv_GB',
#        'Ligand_Solv_SA', 'Ligand_vdW', 'Complex_Energy', 'Complex_Coulomb',
#        'Complex_Covalent', 'Complex_Hbond', 'Complex_Lipo', 'Complex_Packing',
#        'Complex_SelfCont', 'Complex_Solv_GB', 'Complex_Solv_SA', 'Complex_vdW',
# ...

# %%
dg_bind = data1["MMGBSA_dG_Bind"]
dG_Bind_Coulomb = data1["MMGBSA_dG_Bind_Coulomb"]

# %%
fig = plt.figure(figsize=(15,10))
plt.bar(dg_bind, dG_Bind_Coulomb)
# Out:
# <BarContainer object of 101 artists>
